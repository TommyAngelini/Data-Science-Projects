# %% [markdown]
# # Average Temperature Predictions Based on Proposed Greenhouse Emissions in The Next Century
#
# **Goal**: This project will use data on global and country-specific temperatures in the past, as well as greenhouse emissions, to provide predictions on global and country-specific temperatures in the future according to the proposed reductions in greenhouse emissions that various countries and regions have put forward at relevant climate conferences.

# %% [markdown]
# # Data
#
# **Global Land Temperatures By City**: https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data <br>
# **Greenhouse Gas Inventory Data**: https://www.kaggle.com/unitednations/international-greenhouse-gas-emissions <br>
# **Climate Watch Pathways**: https://datasets.wri.org/dataset/cait-emissions-projections <br>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %% [markdown]
# # Loading Historical Global Land Temperatures Data

# %%
historicalTemps = pd.read_csv("EarthSurfaceTempData/GlobalLandTemperaturesByCountry.csv")
historicalTemps.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland
# 5  1744-04-01               1.530                          4.680   Åland
# 6  1744-05-01               6.702                          1.789   Åland
# 7  1744-06-01              11.609                          1.577   Åland
# 8  1744-07-01              15.342                          1.410   Åland
# 9  1744-08-01                 NaN                            NaN   Åland

# %% [markdown]
# # Cleaning up Historical Global Land Temperatures Data
# Here I clean the dataframe to remove NaN values, and to take average temperature data for each country annually, instead of keeping the monthly data. This is because the GHG emission data is yearly and thus I want to match the time series correctly.

# %%
# separate dt column to have years 
historicalTemps['year'] = pd.DatetimeIndex(historicalTemps['dt']).year

# remove NaNs
historicalTemps = historicalTemps.dropna()

# snip all data from before 1990
historicalTemps = historicalTemps[historicalTemps['year'] > 1989]

# average yearly data to have one entry per year
yearlyAvgs = historicalTemps.groupby(
    ["year", "Country"])["AverageTemperature"].mean().reset_index()

yearlyAvgsUnc = historicalTemps.groupby(
    ["year", "Country"])["AverageTemperatureUncertainty"].mean().reset_index()

# combine uncertainty and temperature values together
yearlyAvgs['AverageTemperatureUncertainty'] = yearlyAvgsUnc['AverageTemperatureUncertainty']

# %% [markdown]
# # Loading Historical Global GHGs Emission Data

# %%
historicalGHGs = pd.read_csv("GreenhouseGasInventoryData/greenhouse_gas_inventory_data.csv")
historicalGHGs.head(10)
# Out:
#   country_or_area  year          value  \
# 0       Australia  2014  393126.946994
# 1       Australia  2013  396913.936530
# 2       Australia  2012  406462.847704
# 3       Australia  2011  403705.528314
# 4       Australia  2010  406200.993184
# 5       Australia  2009  408448.479000
# 6       Australia  2008  404237.828214
# 7       Australia  2007  398816.453544
# 8       Australia  2006  391134.100909
# 9       Australia  2005  385581.132806
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...
# 5  carbon_dioxide_co2_emissions_without_land_use_...
# 6  carbon_dioxide_co2_emissions_without_land_use_...
# 7  carbon_dioxide_co2_emissions_without_land_use_...
# 8  carbon_dioxide_co2_emissions_without_land_use_...
# 9  carbon_dioxide_co2_emissions_without_land_use_...

# %% [markdown]
# # Cleaning up Historical Global GHGs Emission Data
# Here I clean up the GHG emission data to remove 2014 entries (since the temperature data only goes until 2013) and to clean up the categorical labels for easier analysis

# %%
# remove 2014 entries
historicalGHGs = historicalGHGs[historicalGHGs['year'] < 2014]
historicalGHGs.head(10)

# Shorten Catgory Names
historicalGHGs['category'].replace(
    {'carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent':'CO2',
    'greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent':'GHG',
    'greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent':'GHG-Indirect-CO2',
    'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent':'HFC',
    'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent':'CH4',
    'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent':'NF3',
    'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent':'N2O',
    'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent':'PFCs',
    'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent':'SF6',
    'unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent':'HFC-PFC-mix'
    }, 
    
    inplace = True)

# %% [markdown]
# ## Investigating the "Category" Variable

# %%
# plot number of occurences of each category in the dataframe
countPlot = sns.countplot(x="category", palette = "ch:.25", data = historicalGHGs)
countPlot.set_xticklabels(countPlot.get_xticklabels(), rotation=90)
countPlot.set_title("Number of occurences of each category")

# print the different categorical labels
print(historicalGHGs['category'].unique())
# Out:
# ['CO2' 'GHG-Indirect-CO2' 'GHG' 'HFC' 'CH4' 'NF3' 'N2O' 'PFCs' 'SF6'
#  'HFC-PFC-mix']

# %%
# plot the distribution of emission values for each categorical label 
boxPlot = sns.boxplot(x='category', y = 'value', data = historicalGHGs)
boxPlot.set_xticklabels(countPlot.get_xticklabels(), rotation=90)
boxPlot.set_yscale("log")
boxPlot.set_title("Distribution of emissions (kilotons CO2 equivalent) by each category of emission")
boxPlot.set_ylabel("Kilotons CO2 Equivalent")
# Out:
# Text(0, 0.5, 'Kilotons CO2 Equivalent')

# %% [markdown]
# # Combining Temperature and Emission Data
# Here I'll combine the two datasets to match countries with their respective average yearly temperatures and emission totals

# %%
# yearlyAvgs, historicalGHGs

# change historicalGHGs "country_or_area" column to "country"
historicalGHGs.rename(columns={'country_or_area':'Country'}, inplace = True)
historicalGHGs['Country'].replace({'United States of America':'United States'}, inplace = True)

# merge the two datasets
tempEmissionData = pd.merge(yearlyAvgs, historicalGHGs, on=["Country", "year"])

# rename "value" and "category column to be more descriptive"
tempEmissionData.rename(columns={'category': 'GreenhouseEmissionType', 'value' : 'EmissionsKilotonnesCO2Equivalent'}, inplace=True)
tempEmissionData
# Out:
#       year        Country  AverageTemperature  AverageTemperatureUncertainty  \
# 0     1990      Australia           22.355750                       0.185750
# 1     1990      Australia           22.355750                       0.185750
# 2     1990      Australia           22.355750                       0.185750
# 3     1990      Australia           22.355750                       0.185750
# 4     1990      Australia           22.355750                       0.185750
# ...    ...            ...                 ...                            ...
# 7631  2013  United States           11.297111                       0.318778
# 7632  2013  United States           11.297111                       0.318778
# 7633  2013  United States           11.297111                       0.318778
# 7634  2013  United States           11.297111                       0.318778
# 7635  2013  United States           11.297111                       0.318778
#
#       EmissionsKilotonnesCO2Equivalent GreenhouseEmissionType
# 0                        278265.898941                    CO2
# 1                        418623.049563       GHG-Indirect-CO2
# 2                        418623.049563                    GHG
# 3                          1424.683520                    HFC
# 4                        118768.837813                    CH4
# ...                                ...                    ...
# 7631                        600.342163                    NF3
# 7632                     403349.746652                    N2O
# 7633                       5858.174564                   PFCs
# 7634                       7229.068816                    SF6
# 7635                       8993.807245            HFC-PFC-mix
#
# [7636 rows x 6 columns]

# %%
# add column with total GHG emission of a country on a yearly basis. This could be useful for modeling later.

groupedEmissions = tempEmissionData.groupby(['Country', 'year'])['EmissionsKilotonnesCO2Equivalent'].sum().reset_index()
groupedEmissions.rename(columns={'EmissionsKilotonnesCO2Equivalent':'yearlyEmissionsKT'}, inplace=True)

# remerge dataframe with new 'yearlyEmissionsKT' included
tempEmissionData = pd.merge(tempEmissionData, groupedEmissions, on=['Country','year'])
tempEmissionData
# Out:
#       year        Country  AverageTemperature  AverageTemperatureUncertainty  \
# 0     1990      Australia           22.355750                       0.185750
# 1     1990      Australia           22.355750                       0.185750
# 2     1990      Australia           22.355750                       0.185750
# 3     1990      Australia           22.355750                       0.185750
# 4     1990      Australia           22.355750                       0.185750
# ...    ...            ...                 ...                            ...
# 7631  2013  United States           11.297111                       0.318778
# 7632  2013  United States           11.297111                       0.318778
# 7633  2013  United States           11.297111                       0.318778
# 7634  2013  United States           11.297111                       0.318778
# 7635  2013  United States           11.297111                       0.318778
#
#       EmissionsKilotonnesCO2Equivalent GreenhouseEmissionType  \
# 0                        278265.898941                    CO2
# 1                        418623.049563       GHG-Indirect-CO2
# 2                        418623.049563                    GHG
# 3                          1424.683520                    HFC
# 4                        118768.837813                    CH4
# ...                                ...                    ...
# 7631                        600.342163                    NF3
# 7632                     403349.746652                    N2O
# 7633                       5858.174564                   PFCs
# 7634                       7229.068816                    SF6
# 7635                       8993.807245            HFC-PFC-mix
#
#       yearlyEmissionsKT
# 0          1.255869e+06
# 1          1.255869e+06
# 2          1.255869e+06
# 3          1.255869e+06
# 4          1.255869e+06
# ...                 ...
# 7631       2.039994e+07
# 7632       2.039994e+07
# 7633       2.039994e+07
# 7634       2.039994e+07
# 7635       2.039994e+07
#
# [7636 rows x 7 columns]

# %% [markdown]
# # Saving cleaned dataframe to csv

# %%
tempEmissionData.to_csv('tempEmissionDataCleaned.csv', index = False)

# %%
df = pd.read_csv('tempEmissionDataCleaned.csv')
df
# Out:
#       year        Country  AverageTemperature  AverageTemperatureUncertainty  \
# 0     1990      Australia           22.355750                       0.185750
# 1     1990      Australia           22.355750                       0.185750
# 2     1990      Australia           22.355750                       0.185750
# 3     1990      Australia           22.355750                       0.185750
# 4     1990      Australia           22.355750                       0.185750
# ...    ...            ...                 ...                            ...
# 7631  2013  United States           11.297111                       0.318778
# 7632  2013  United States           11.297111                       0.318778
# 7633  2013  United States           11.297111                       0.318778
# 7634  2013  United States           11.297111                       0.318778
# 7635  2013  United States           11.297111                       0.318778
#
#       EmissionsKilotonnesCO2Equivalent GreenhouseEmissionType  \
# 0                        278265.898941                    CO2
# 1                        418623.049563       GHG-Indirect-CO2
# 2                        418623.049563                    GHG
# 3                          1424.683520                    HFC
# 4                        118768.837813                    CH4
# ...                                ...                    ...
# 7631                        600.342163                    NF3
# 7632                     403349.746652                    N2O
# 7633                       5858.174564                   PFCs
# 7634                       7229.068816                    SF6
# 7635                       8993.807245            HFC-PFC-mix
#
#       yearlyEmissionsKT
# 0          1.255869e+06
# 1          1.255869e+06
# 2          1.255869e+06
# 3          1.255869e+06
# 4          1.255869e+06
# ...                 ...
# 7631       2.039994e+07
# 7632       2.039994e+07
# 7633       2.039994e+07
# 7634       2.039994e+07
# 7635       2.039994e+07
#
# [7636 rows x 7 columns]

# %% [markdown]
# # Exploratory Data Analysis
# Here I'll look into relationships between the average temperature and emission of countries over time, looking at both yearly total emissions and specific types of emissions

# %%
df.describe()
# Out:
#               year  AverageTemperature  AverageTemperatureUncertainty  \
# count  7636.000000         7636.000000                    7636.000000
# mean   2001.704557            9.154605                       0.261866
# std       6.866960            6.429697                       0.097319
# min    1990.000000          -19.000417                       0.127917
# 25%    1996.000000            7.226500                       0.209667
# 50%    2002.000000            9.697750                       0.238583
# 75%    2008.000000           12.311125                       0.281083
# max    2013.000000           22.896833                       0.982500
#
#        EmissionsKilotonnesCO2Equivalent  yearlyEmissionsKT
# count                      7.636000e+03       7.636000e+03
# mean                       1.448595e+05       1.324020e+06
# std                        6.583695e+05       3.643368e+06
# min                        1.103750e-06       2.601849e+02
# 25%                        2.641857e+02       1.280427e+05
# 50%                        7.105387e+03       2.408950e+05
# 75%                        5.981711e+04       1.241770e+06
# max                        7.422208e+06       2.226662e+07

# %%
df.AverageTemperature.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df.AverageTemperatureUncertainty.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
yrlyEmissionHist = df.yearlyEmissionsKT.hist(bins=20, edgecolor='black', range = [0,100000])

# %%
hist = df.EmissionsKilotonnesCO2Equivalent.hist(bins = 15, edgecolor = 'black', range = [0, 10000])
# hist.set_xscale('log')

# %%
boxplot = df.boxplot(column= ['AverageTemperature'])

# %%
boxplot = df.boxplot(column= ['yearlyEmissionsKT'])
boxplot.set_yscale('log')

# %%
boxplot = df.boxplot(column= ['EmissionsKilotonnesCO2Equivalent'])
boxplot.set_yscale('log')

# %% [markdown]
# ### Looking at correlations

# %%
correlations = df[['AverageTemperature', 'yearlyEmissionsKT', 'EmissionsKilotonnesCO2Equivalent', 'AverageTemperatureUncertainty']].corr()
correlations
# Out:
#                                   AverageTemperature  yearlyEmissionsKT  \
# AverageTemperature                          1.000000           0.037536
# yearlyEmissionsKT                           0.037536           1.000000
# EmissionsKilotonnesCO2Equivalent            0.024435           0.553624
# AverageTemperatureUncertainty              -0.483489          -0.248285
#
#                                   EmissionsKilotonnesCO2Equivalent  \
# AverageTemperature                                        0.024435
# yearlyEmissionsKT                                         0.553624
# EmissionsKilotonnesCO2Equivalent                          1.000000
# AverageTemperatureUncertainty                            -0.142906
#
#                                   AverageTemperatureUncertainty
# AverageTemperature                                    -0.483489
# yearlyEmissionsKT                                     -0.248285
# EmissionsKilotonnesCO2Equivalent                      -0.142906
# AverageTemperatureUncertainty                          1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(correlations, cmap=cmap, vmax=.4, center = 0, 
           square = True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
num = df['GreenhouseEmissionType'].value_counts()
bar = sns.barplot(x=num.index, y = num)
bar.set_xticklabels(bar.get_xticklabels(), rotation=60)
# Out:
# [Text(0, 0, 'GHG'),
#  Text(1, 0, 'CO2'),
#  Text(2, 0, 'N2O'),
#  Text(3, 0, 'CH4'),
#  Text(4, 0, 'SF6'),
#  Text(5, 0, 'HFC'),
#  Text(6, 0, 'GHG-Indirect-CO2'),
#  Text(7, 0, 'PFCs'),
#  Text(8, 0, 'NF3'),
#  Text(9, 0, 'HFC-PFC-mix')]

# %%
df.columns
# Out:
# Index(['year', 'Country', 'AverageTemperature',
#        'AverageTemperatureUncertainty', 'EmissionsKilotonnesCO2Equivalent',
#        'GreenhouseEmissionType', 'yearlyEmissionsKT'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'Country', values = 'AverageTemperature').sort_values('AverageTemperature', ascending = False)
# Out:
#                 AverageTemperature
# Country
# Australia                22.222064
# Cyprus                   19.642929
# Malta                    19.448113
# Portugal                 15.585812
# Greece                   15.560694
# Spain                    14.546019
# France                   13.768394
# Italy                    13.750792
# Japan                    12.818330
# Turkey                   12.482128
# Croatia                  12.404132
# Bulgaria                 11.432563
# New Zealand              10.909082
# Slovenia                 10.779492
# Hungary                  10.771085
# Netherlands              10.550299
# Belgium                  10.519808
# Luxembourg               10.219698
# Ireland                  10.207519
# Monaco                   10.077128
# Romania                   9.780465
# United States             9.594022
# United Kingdom            9.345969
# Germany                   9.244503
# Ukraine                   8.913895
# Czech Republic            8.726606
# Poland                    8.592926
# Slovakia                  8.581743
# Switzerland               8.076341
# Austria                   7.321388
# Lithuania                 7.149047
# Belarus                   7.136079
# Latvia                    6.594538
# Estonia                   6.086809
# Liechtenstein             5.744500
# Sweden                    3.562549
# Finland                   2.493491
# Iceland                   2.272692
# Norway                    1.218030
# Canada                   -3.795658
# Denmark                 -16.865944

# %%
pd.pivot_table(df, index = ['Country'], values = 'yearlyEmissionsKT').sort_values('yearlyEmissionsKT', ascending = False)
# Out:
#                 yearlyEmissionsKT
# Country
# United States        2.085410e+07
# Japan                4.063578e+06
# Germany              3.141105e+06
# Canada               2.118283e+06
# France               1.629873e+06
# Italy                1.598165e+06
# Ukraine              1.516390e+06
# Australia            1.452928e+06
# United Kingdom       1.406054e+06
# Poland               1.244780e+06
# Turkey               9.429527e+05
# Spain                7.099337e+05
# Netherlands          6.568954e+05
# Romania              4.744912e+05
# Czech Republic       4.492546e+05
# Belgium              4.267916e+05
# Greece               3.598707e+05
# Belarus              2.709258e+05
# Austria              2.498629e+05
# New Zealand          2.285141e+05
# Portugal             2.282210e+05
# Hungary              2.220899e+05
# Finland              2.186159e+05
# Denmark              2.142492e+05
# Sweden               2.048142e+05
# Ireland              1.917621e+05
# Norway               1.614289e+05
# Switzerland          1.594268e+05
# Slovakia             1.561056e+05
# Bulgaria             1.347125e+05
# Croatia              7.876743e+04
# Lithuania            7.216070e+04
# Estonia              6.224936e+04
# Slovenia             5.818715e+04
# Latvia               3.900292e+04
# Cyprus               2.469857e+04
# Luxembourg           2.305828e+04
# Iceland              1.208009e+04
# Malta                8.340308e+03
# Liechtenstein        4.915837e+02
# Monaco               3.029129e+02
